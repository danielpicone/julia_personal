# %%
include("data_creation.jl")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32ae72510>)
# 1000×2 DataFrames.DataFrame
# │ Row  │ x         │ y         │
# ├──────┼───────────┼───────────┤
# │ 1    │ 4.37717   │ -0.761737 │
# │ 2    │ 4.97361   │ -0.761295 │
# │ 3    │ 4.70537   │ -0.826042 │
# │ 4    │ -1.45096  │ -1.48746  │
# │ 5    │ 3.21096   │ 0.167098  │
# │ 6    │ 5.59501   │ -0.193464 │
# │ 7    │ -2.88057  │ -0.176439 │
# │ 8    │ 3.74984   │ -0.889868 │
# ⋮
# │ 992  │ 5.40344   │ -0.574453 │
# │ 993  │ -2.71356  │ -0.771438 │
# │ 994  │ -2.7176   │ -0.515899 │
# │ 995  │ 1.19698   │ 0.581259  │
# │ 996  │ 1.34354   │ 0.912328  │
# │ 997  │ -0.856816 │ -0.587841 │
# │ 998  │ 1.44548   │ 1.23676   │
# │ 999  │ 2.90103   │ 0.34062   │
# │ 1000 │ 2.50272   │ 0.723944  │
# CSV.Sink(    CSV.Options:
#         delim: ','
#         quotechar: '"'
#         escapechar: '\\'
#         null: ""
# ...

# %%
include("metaheuristic/FA.jl")
# Out:
# WARNING: Method definition intensity(Any, Any, Any) in module Main at /Users/danielpicone/Documents/GitHub/julia_personal/metaheuristic_working/FA.jl:49 overwritten at /Users/danielpicone/Documents/GitHub/julia_personal/metaheuristic/FA.jl:49.
# WARNING: Method definition #intensity(Array{Any, 1}, Main.#intensity, Any, Any, Any) in module Main overwritten.
# WARNING: Method definition fa(Any) in module Main at /Users/danielpicone/Documents/GitHub/julia_personal/metaheuristic_working/FA.jl:69 overwritten at /Users/danielpicone/Documents/GitHub/julia_personal/metaheuristic/FA.jl:69.
# WARNING: Method definition #fa(Array{Any, 1}, Main.#fa, Any) in module Main overwritten.
# WARNING: replacing docs for 'fa :: Tuple{Any}' in module 'Main'.
# fa

# %%
dim = 1
function f(x)
    return x^2
end
# Out:
# WARNING: Method definition f(Any) in module Main at In[17]:3 overwritten at In[20]:3.
# f (generic function with 1 method)

# %%
fa(f, bounds = bounds)
# Out:
# MethodError: no method matching *(::Array{Float64,1}, ::Array{Float64,1})
# Closest candidates are:
#   *(::Any, ::Any, ::Any, ::Any...) at operators.jl:138
#   *(::PyCall.PyObject, ::Any) at /Users/danielpicone/.julia/v0.5/PyCall/src/pyoperators.jl:11
#   *{T,N}(::DataArrays.NAtype, ::AbstractArray{T,N}) at /Users/danielpicone/.julia/v0.5/DataArrays/src/operators.jl:707
#   ...
#
#  in power_by_squaring(::Array{Float64,1}, ::Int64) at ./intfuncs.jl:116
#  in collect(::Base.Generator{UnitRange{Int64},##43#47{Array{Float64,2},#f,Array{Array{Float64,1},2}}}) at ./array.jl:307
#  in #fa#41(::Array{Float64,2}, ::Int64, ::Int64, ::Int64, ::Float64, ::Float64, ::Int64, ::String, ::String, ::#fa, ::#f) at /Users/danielpicone/Documents/GitHub/julia_personal/metaheuristic/FA.jl:85
#  in (::#kw##fa)(::Array{Any,1}, ::#fa, ::Function) at ./<missing>:0
#  in include_string(::String, ::String) at ./loading.jl:441
# ...
