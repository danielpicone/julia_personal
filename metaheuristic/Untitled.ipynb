# %%
include("nn.jl")
# Out:
# Training now
# The total loss is: 104154.06409661213
# Trying nn now
# We are up to iteration 100 out of 1000
# We are up to iteration 200 out of 1000
# We are up to iteration 300 out of 1000
# We are up to iteration 400 out of 1000
# We are up to iteration 500 out of 1000
# We are up to iteration 600 out of 1000
# We are up to iteration 700 out of 1000
# We are up to iteration 800 out of 1000
# We are up to iteration 900 out of 1000
# 38485.0173934172
# ...
